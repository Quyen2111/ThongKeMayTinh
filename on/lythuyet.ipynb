# %% [markdown]
# Dưới đây là ví dụ minh họa từng hàm với giải thích cụ thể:
#
# 1. Random Variates (rvs) – Tạo mẫu ngẫu nhiên từ phân phối
# Tạo 10 mẫu ngẫu nhiên từ phân phối chuẩn có trung bình 0 và độ lệch chuẩn 1.
#
# python
# Sao chép
# Chỉnh sửa
# samples = norm.rvs(loc=0, scale=1, size=10)
# print(samples)
# 📌 Giải thích: Lấy 10 giá trị ngẫu nhiên từ phân phối chuẩn
# 𝑁
# (
# 0
# ,
# 1
# )
# N(0,1).
#
# 2. Probability Mass Function (pmf) – Hàm xác suất của phân phối rời rạc
# Ví dụ với phân phối nhị thức (Binomial):
#
# python
# Sao chép
# Chỉnh sửa
# p = 0.5  # Xác suất thành công
# n = 10   # Số lần thử
# x = 5    # Số lần thành công
# prob = binom.pmf(x, n, p)
# print(prob)
# 📌 Giải thích: Tính xác suất có chính xác 5 lần thành công trong 10 lần thử với xác suất mỗi lần thành công là 0.5.
#
# 3. Probability Density Function (pdf) – Hàm mật độ của phân phối liên tục
# Ví dụ với phân phối chuẩn:
#
# python
# Sao chép
# Chỉnh sửa
# x = 0  # Giá trị cần tính mật độ
# density = norm.pdf(x, loc=0, scale=1)
# print(density)
# 📌 Giải thích: Tính giá trị mật độ xác suất tại
# 𝑥
# =
# 0
# x=0 cho phân phối chuẩn
# 𝑁
# (
# 0
# ,
# 1
# )
# N(0,1).
#
# 4. Cumulative Distribution Function (cdf) – Hàm phân phối tích lũy
# Ví dụ với phân phối chuẩn:
#
# python
# Sao chép
# Chỉnh sửa
# x = 0  # Giá trị cần tính
# cumulative_prob = norm.cdf(x, loc=0, scale=1)
# print(cumulative_prob)
# 📌 Giải thích: Tính xác suất
# 𝑃
# (
# 𝑋
# ≤
# 0
# )
# P(X≤0) của phân phối chuẩn
# 𝑁
# (
# 0
# ,
# 1
# )
# N(0,1).
#
# 5. Percent Point Function (ppf) – Tìm điểm phân vị
# Ví dụ với phân phối chuẩn, tìm giá trị ứng với phân vị 95%:
#
# python
# Sao chép
# Chỉnh sửa
# quantile = norm.ppf(0.95, loc=0, scale=1)
# print(quantile)
# 📌 Giải thích: Tìm giá trị
# 𝑥
# x sao cho
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# =
# 0.95
# P(X≤x)=0.95.
#
# 6. Survival Function (sf) – Hàm survival
# Ví dụ với phân phối chuẩn:
#
# python
# Sao chép
# Chỉnh sửa
# x = 0  # Giá trị cần tính
# survival_prob = norm.sf(x, loc=0, scale=1)
# print(survival_prob)
# 📌 Giải thích: Tính xác suất
# 𝑃
# (
# 𝑋
# >
# 0
# )
# P(X>0), tức là
# 1
# −
# 𝐶
# 𝐷
# 𝐹
# (
# 0
# )
# 1−CDF(0).
#
# 7. Inverse Survival Function (isf) – Hàm ngược của hàm survival
# Ví dụ với phân phối chuẩn:
#
# python
# Sao chép
# Chỉnh sửa
# quantile = norm.isf(0.05, loc=0, scale=1)
# print(quantile)
# 📌 Giải thích: Tìm giá trị
# 𝑥
# x sao cho
# 𝑃
# (
# 𝑋
# >
# 𝑥
# )
# =
# 0.05
# P(X>x)=0.05, tương đương với
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# =
# 0.95
# P(X≤x)=0.95.
#
# 🔎 Tóm tắt:
#
# rvs → Lấy mẫu ngẫu nhiên
#
# pmf → Xác suất của phân phối rời rạc
#
# pdf → Mật độ của phân phối liên tục
#
# cdf → Xác suất tích lũy
#
# ppf → Điểm phân vị (ngược của CDF)
#
# sf → Xác suất vượt quá giá trị đã cho
#
# isf → Ngược của SF (tương tự như ppf nhưng dùng SF)

# %% [markdown]
# 1. Phân phối Nhị Thức (Binomial Distribution)
# Dùng khi có n lần thử độc lập với xác suất thành công
# 𝑝
# p.
#
# Random Variates (rvs)
# Tạo 10 mẫu từ phân phối nhị thức với
# 𝑛
# =
# 10
# ,
# 𝑝
# =
# 0.5
# n=10,p=0.5.
#
# python
# Sao chép
# Chỉnh sửa
# binomial_samples = binom.rvs(n=10, p=0.5, size=10)
# print(binomial_samples)
# Probability Mass Function (pmf)
# Tính xác suất có 5 lần thành công trong 10 lần thử với xác suất thành công là 0.5.
#
# python
# Sao chép
# Chỉnh sửa
# prob_binom = binom.pmf(k=5, n=10, p=0.5)
# print(prob_binom)
# Cumulative Distribution Function (cdf)
# Xác suất có tối đa 5 lần thành công (tức là
# 𝑃
# (
# 𝑋
# ≤
# 5
# )
# P(X≤5)).
#
# python
# Sao chép
# Chỉnh sửa
# cumulative_binom = binom.cdf(k=5, n=10, p=0.5)
# print(cumulative_binom)
# Percent Point Function (ppf)
# Tìm số lần thành công sao cho xác suất tích lũy là 0.95.
#
# python
# Sao chép
# Chỉnh sửa
# quantile_binom = binom.ppf(0.95, n=10, p=0.5)
# print(quantile_binom)
# Survival Function (sf)
# Tính xác suất có hơn 5 lần thành công (tức là
# 𝑃
# (
# 𝑋
# >
# 5
# )
# P(X>5)).
#
# python
# Sao chép
# Chỉnh sửa
# survival_binom = binom.sf(k=5, n=10, p=0.5)
# print(survival_binom)
# 2. Phân phối Poisson (Poisson Distribution)
# Dùng để mô hình hóa số lần xảy ra sự kiện trong một khoảng thời gian/khu vực với tốc độ trung bình
# 𝜆
# λ.
#
# Random Variates (rvs)
# Tạo 10 mẫu ngẫu nhiên từ phân phối Poisson với
# 𝜆
# =
# 3
# λ=3.
#
# python
# Sao chép
# Chỉnh sửa
# poisson_samples = poisson.rvs(mu=3, size=10)
# print(poisson_samples)
# Probability Mass Function (pmf)
# Xác suất có chính xác 4 sự kiện xảy ra khi
# 𝜆
# =
# 3
# λ=3.
#
# python
# Sao chép
# Chỉnh sửa
# prob_poisson = poisson.pmf(k=4, mu=3)
# print(prob_poisson)
# Cumulative Distribution Function (cdf)
# Xác suất có tối đa 4 sự kiện xảy ra (tức là
# 𝑃
# (
# 𝑋
# ≤
# 4
# )
# P(X≤4)).
#
# python
# Sao chép
# Chỉnh sửa
# cumulative_poisson = poisson.cdf(k=4, mu=3)
# print(cumulative_poisson)
# Percent Point Function (ppf)
# Tìm số sự kiện sao cho xác suất tích lũy là 0.95.
#
# python
# Sao chép
# Chỉnh sửa
# quantile_poisson = poisson.ppf(0.95, mu=3)
# print(quantile_poisson)
# Survival Function (sf)
# Xác suất có hơn 4 sự kiện xảy ra (tức là
# 𝑃
# (
# 𝑋
# >
# 4
# )
# P(X>4)).
#
# python
# Sao chép
# Chỉnh sửa
# survival_poisson = poisson.sf(k=4, mu=3)
# print(survival_poisson)
# 3. Phân phối Chuẩn (Normal Distribution)
# (Đã có ở trên, nhưng đây là tóm tắt nhanh)
#
# python
# Sao chép
# Chỉnh sửa
# samples = norm.rvs(loc=0, scale=1, size=10)  # Lấy mẫu ngẫu nhiên
# prob_density = norm.pdf(0, loc=0, scale=1)  # Hàm mật độ
# cumulative_prob = norm.cdf(0, loc=0, scale=1)  # Phân phối tích lũy
# quantile = norm.ppf(0.95, loc=0, scale=1)  # Phân vị
# survival_prob = norm.sf(0, loc=0, scale=1)  # Hàm survival
# 📌 Tóm tắt cách dùng các hàm quan trọng:
#
# Hàm	Binomial	Poisson	Normal
# rvs	binom.rvs(n, p, size)	poisson.rvs(mu, size)	norm.rvs(loc, scale, size)
# pmf	binom.pmf(k, n, p)	poisson.pmf(k, mu)	Không có (vì là liên tục)
# pdf	Không có (vì là rời rạc)	Không có	norm.pdf(x, loc, scale)
# cdf	binom.cdf(k, n, p)	poisson.cdf(k, mu)	norm.cdf(x, loc, scale)
# ppf	binom.ppf(q, n, p)	poisson.ppf(q, mu)	norm.ppf(q, loc, scale)
# sf	binom.sf(k, n, p)	poisson.sf(k, mu)	norm.sf(x, loc, scale)
