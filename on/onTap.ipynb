# %% [markdown]
# <a href="https://colab.research.google.com/github/DanhOMO/ThongKeMayTinh/blob/main/onTap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/diem_thi_thpt_2022.csv')

# %%
df.head(5)
# Out:
#        sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_li  gdcd
# 0     6.0  8.75
# 1     7.5  8.25
# 2     5.5  8.75
# 3     6.5  7.50
# 4     8.5  8.25

# %%
# Out:
# sbd               0
# toan          12715
# ngu_van       14034
# ngoai_ngu    124832
# vat_li       669918
# hoa_hoc      668074
# sinh_hoc     673243
# lich_su      335779
# dia_li       338020
# gdcd         441098
# dtype: int64

# %%
diemThi = df.iloc[:,1:]
diemThi.mean()
# Out:
# toan         6.466254
# ngu_van      6.507746
# ngoai_ngu    5.157686
# vat_li       6.723779
# hoa_hoc      6.703898
# sinh_hoc     5.019109
# lich_su      6.343930
# dia_li       6.677929
# gdcd         8.033266
# dtype: float64

# %%
import matplotlib.pyplot as plt
mon = ['toan', 'ngoai_ngu', 'ngu_van']
plt.bar(mon, diemThi[mon].mean())
plt.legend()
plt.show()
# Out:
# <ipython-input-16-a8a4747a5765>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
test = df[df['toan'].notna()]
pd.concat([test.sort_values(by='toan', ascending=False).head(20),test.sort_values(by='toan', ascending=True).head(20)])
# Out:
#              sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 793102  48011217  10.0     6.25        9.4    8.25     4.25      4.00
# 15616    1015777  10.0     5.75        NaN    7.00     6.50      4.75
# 466151  26017925  10.0     7.50        9.4    9.50     7.00      7.00
# 102268   2005344  10.0     6.00        NaN    8.00     9.75      9.00
# 499676  28020828  10.0     7.75        7.6    9.25     9.25      5.25
# 294032  15000207  10.0     7.75        9.6    8.00     9.75      9.50
# 475354  27006879  10.0     7.25        6.0    9.50     9.25      7.00
# 139162   2042310  10.0     7.00        8.6    7.25    10.00      8.75
# 17690    1017880  10.0     5.00        9.2    7.00     8.25      6.75
# 558663  30005646  10.0     6.00        6.4    6.25     9.75      9.25
# 149423   2052657  10.0     6.50        7.0    8.25     8.75      6.75
# 520517  29004083  10.0     7.75        5.0    6.25     9.25      9.50
# ...

# %%
print((df['toan'] == 10).sum())
# Out:
# 35

# %%
monXH = ['dia_li', 'lich_su', 'gdcd']
monTN = ['sinh_hoc', 'hoa_hoc', 'vat_li']

# %%
so_hs_khtn = df.dropna(subset=["vat_li", "hoa_hoc", "sinh_hoc"]).shape[0]

# Học sinh thi KHXH: Có điểm cả 3 môn Sử, Địa, GDCD
so_hs_khxh = df.dropna(subset=["lich_su", "dia_li", "gdcd"]).shape[0]
print(so_hs_khtn, so_hs_khxh)
# Out:
# 318685 554090

# %%
plt.bar( ['XH', 'TN'],[KHXH.sum(), KHTNN.sum()])
# Out:
# <BarContainer object of 2 artists>

# %%
df['DXTN'] = (df['toan'] + df['ngu_van'] + df['ngoai_ngu'] +
              df[[ 'vat_li', 'dia_li', 'sinh_hoc', 'hoa_hoc', 'gdcd', 'lich_su']].max(axis=1))/4

# %%
plt.hist(df['DXTN'])
plt.show()

# %%
df1 = df.dropna(subset=['toan', 'ngu_van', 'ngoai_ngu'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 866730 entries, 0 to 995440
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   sbd        866730 non-null  int64
#  1   toan       866730 non-null  float64
#  2   ngu_van    866730 non-null  float64
#  3   ngoai_ngu  866730 non-null  float64
#  4   vat_li     309447 non-null  float64
#  5   hoa_hoc    309368 non-null  float64
#  6   sinh_hoc   309221 non-null  float64
#  7   lich_su    551675 non-null  float64
#  8   dia_li     551512 non-null  float64
#  9   gdcd       549678 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 72.7 MB

# %%
print(df.iloc[:,1:].mean())
print(df.iloc[:,1:].min())
print(df.iloc[:,1:].max())
# Out:
# toan         6.466254
# ngu_van      6.507746
# ngoai_ngu    5.157686
# vat_li       6.723779
# hoa_hoc      6.703898
# sinh_hoc     5.019109
# lich_su      6.343930
# dia_li       6.677929
# gdcd         8.033266
# dtype: float64
# toan         0.0
# ngu_van      0.0
# ngoai_ngu    0.0
# vat_li       0.0
# hoa_hoc      0.0
# sinh_hoc     0.0
# lich_su      0.0
# dia_li       0.0
# gdcd         0.0
# dtype: float64
# toan         10.0
# ngu_van      10.0
# ngoai_ngu    10.0
# vat_li       10.0
# hoa_hoc      10.0
# sinh_hoc     10.0
# lich_su      10.0
# dia_li       10.0
# gdcd         10.0
# dtype: float64

# %%
plt.bar(['toan','ngoai_ngu','ngu_van'], df[['toan', 'ngoai_ngu', 'ngu_van']].mean())
plt.show()

# %%
khxh = df.dropna(subset=['dia_li', 'lich_su', 'gdcd'])
khtn = df.dropna(subset=['sinh_hoc', 'hoa_hoc', 'vat_li'])

# Lọc học sinh bị thiếu toàn bộ 3 môn chính
nghihoc = df[df[['toan', 'ngu_van', 'ngoai_ngu']].isnull().all(axis=1)]

print("Số lượng học sinh KHXH =", khxh.shape[0])
print("Số lượng học sinh KHTN =", khtn.shape[0])
print("Số lượng học sinh nghỉ học =", nghihoc.shape[0])
# Out:
# Số lượng học sinh KHXH = 554090
# Số lượng học sinh KHTN = 318685
# Số lượng học sinh nghỉ học = 82

# %%
df['DXTN'] = (df['toan'] + df['ngoai_ngu'] + df['ngu_van']
              + df[['vat_li', 'sinh_hoc', 'hoa_hoc', 'lich_su', 'dia_li', 'gdcd']].max(axis=1))/4

# %%
df.loc[(df['DXTN'] >= 5), 'phan loai'] = 'tb'
df.loc[(df['DXTN'] >= 6.5), 'phan loai'] = 'kha'
df.loc[(df['DXTN'] >= 8), 'phan loai'] = 'gioi'
df.loc[df['DXTN'] >= 9, 'phan loai'] = 'Xs'
df.loc[df['DXTN'] < 5, 'phan loai'] = 'yeu'

# %%
df[['DXTN', 'phan loai']].tail(40)
# Out:
#           DXTN phan loai
# 995401  5.3750        tb
# 995402  5.6000        tb
# 995403  5.6375        tb
# 995404  6.4750        tb
# 995405  5.1250        tb
# 995406  4.1875       yeu
# 995407  5.1875        tb
# 995408  5.3875        tb
# 995409  5.6125        tb
# 995410  6.0000        tb
# 995411  4.7250       yeu
# 995412  5.7125        tb
# 995413  6.1875        tb
# 995414  4.2000       yeu
# 995415  4.6500       yeu
# 995416  6.7750       kha
# 995417  6.9375       kha
# 995418  4.7000       yeu
# 995419  4.5500       yeu
# 995420  5.8000        tb
# 995421  5.7750        tb
# 995422  6.3125        tb
# 995423  5.7625        tb
# 995424  6.3125        tb
# 995425  4.3375       yeu
# 995426  6.8750       kha
# 995427  4.8625       yeu
# 995428  5.8875        tb
# 995429  5.5750        tb
# 995430  5.3125        tb
# 995431  5.9375        tb
# 995432  5.3625        tb
# 995433  6.1375        tb
# 995434  5.2500        tb
# 995435  5.9500        tb
# 995436  7.1875       kha
# ...
