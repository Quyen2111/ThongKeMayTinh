# %% [markdown]
# # Simulation - Mô phỏng & Dữ liệu
#
# Trong bài thực hành này, chúng ta sẽ sử dụng python và numpy để tính toán và thực hiện một số mô phỏng.
#
# Những nội dung sẽ thực hiện trong tài liệu này:
#
# - Mô phỏng dữ liệu
# - Kiểm tra dữ liệu

# %% [markdown]
# ## MÔ PHỎNG

# %% [markdown]
# ### Bài 1: Mô phỏng tung đồng xu cân đối
#
# Giả sử một đồng xu có hai mặt `Head` và `Tail`.
#
# a. Định nghĩa hàm `toss_a_fair_coin`để mô phỏng việc tung đồng xu. Kết quả trả về là `H` hoặc `T` tương ứng với một trong hai mặt
#
# ```python
# def toss_a_fair_coin():
#     # ...
# ```
#
# b. Thực hiện việc tung đồng xu n = 100 lần. Cho biết số lần xuất hiện của mỗi mặt. Lựa chọn đồ thị phù hợp để hiển thị kết quả trên.

# %%
# YOUR CODE HERE
import random

def toss_a_fair_coin():
    return "H" if random.random() < 0.5 else "T"

def toss_a_fair_coin_n_times(n):
    if n < 0:
        raise ValueError("n must be non-negative")
    return [toss_a_fair_coin() for _ in range(n)]

results = toss_a_fair_coin_n_times(100)
print("Number of Heads (H):", results.count("H"))
print("Number of Tails (T):", results.count("T"))

# Ve do thi phu hop
import matplotlib.pyplot as plt
plt.hist(results, bins=2, color='blue', edgecolor='black', linewidth=1.2)
# Out:
# Number of Heads (H): 60
# Number of Tails (T): 40
# (array([60., 40.]), array([0. , 0.5, 1. ]), <BarContainer object of 2 artists>)

# %% [markdown]
# ### Bài 2: Mô phỏng tung đồng xu không cân đối
#
# Giả sử có một đồng xu với hai mặt `H` và `T` không cân đối, với xác suất thu được mặt Head là 0.6, xác suất thu được mặt Tail là 0.4. Bạn hãy:
#
# a. Định nghĩa hàm `toss_a_biased_coin`để mô phỏng việc tung đồng xu. Kết quả trả về là `H` hoặc `T` tương ứng với một trong hai mặt
#
# ```python
# def toss_a_biased_coin(head_prob):
#     '''
#     Tung đồng xu không cân đối.
#     Return: 'H' or 'T'
#         head_prob: xác suất thu được mặt Head
#     '''
#     # ...
# ```
#
# b. Thực hiện việc tung đồng xu n = 100 lần. Cho biết số lần xuất hiện của mỗi mặt. Tính tỷ lệ xuất hiện của mặt Head và Tail. Lựa chọn đồ thị phù hợp để hiển thị kết quả trên.
#
# c. Thực hiện việc tung đồng xu n = 10000 lần. Cho biết số lần xuất hiện của mỗi mặt. Tính tỷ lệ xuất hiện của mặt Head và Tail. Lựa chọn đồ thị phù hợp để hiển thị kết quả trên.
#
# d. Bạn có nhận xét gì?

# %%
# YOUR CODE HERE
# ve do thi
import matplotlib.pyplot as plt
def toss_a_biased_coin(head_prob):
    if head_prob < 0 or head_prob > 1:
        raise ValueError("head_prob must be between 0 and 1")
    import random
    if random.random() < head_prob:
        return "H"
    else:
        return "T"
# thuc hien tung dong xu 100 lan va cho biet so lan suat hien cu amoi mat
def toss_a_biased_coin_n_times(head_prob, n):
    if n < 0:
        raise ValueError("n must be non-negative")
    return [toss_a_biased_coin(head_prob) for _ in range(n)]
tung100lan = toss_a_biased_coin_n_times(0.5, 100)
print(tung100lan.count("H"))
print(tung100lan.count("T"))
# Thuc hien tung dong xu n = 10000 lan 
tung10000lan = toss_a_biased_coin_n_times(0.5, 10000)
print(tung10000lan.count("H"))
print(tung10000lan.count("T"))
# Nhan xet
print("So lan xuat hien cua mat H va mat T hau nhu co gia tri bang nhau")
# ve do thi
plt.hist(tung100lan, bins = 100)
plt.show()
plt.hist(tung10000lan, bins = 100)
plt.show()
# Out:
# 48
# 52
# 5065
# 4935
# So lan xuat hien cua mat H va mat T hau nhu co gia tri bang nhau

# %% [markdown]
# ### Bài 3: Khảo sát hàm randint()
#
# Hàm `randint()`dùng để phát sinh số nguyên ngẫu nhiên. Tuy nhiên, các kết quả ngẫu nhiên này có quy luật nào hay không, liệu ta có thể tin tưởng để sử dụng hàm này không? Trong ví dụ này bạn hãy thực hiện mô phỏng sau: phát sinh `n` số số ngẫu nhiên trong đoạn [1..40]. Với mỗi lần phát sinh bạn hãy vẽ histogram về `tần suất` xuất hiện của mỗi số.
#
# a. Hãy vẽ đồ thị `tần suất` xuất hiện của các số với n=40, n=100, n=10000, n=1000000
#
# b. Hãy đưa ra nhận xét của bạn về hàm `randint()`

# %%
# YOUR CODE HERE
import numpy as np
# Tao ham ramdom tu 1 den 40
data = np.random.randint(1, 41, 40)
data1 = np.random.randint(1, 41,100)
data2 = np.random.randint(1, 41, 10000)
data3 = np.random.randint(1, 41, 1000000)

# ve do thi
import matplotlib.pyplot as plt
plt.hist(data, bins = 40)
plt.show()
plt.hist(data1, bins = 40)
plt.show()
plt.hist(data2, bins = 40)
plt.show()
plt.hist(data3, bins = 40)
plt.show()

# Phan tinh giup toi 
print("Do thi phan phoi xac suat cua 4 truong hop tren deu co hinh dang giong nhau")
print("Ket luan cho ta thay cac du lieu duoc rai rac mot cach ngau nhien va deu theo so luong phan tu duoc tao")
print("So luong cac nhieu thi kha nang du lieu deu se cang cao")
print("Vi du so luong phan tu 40 se khong co do thi dieu voi so luong phan tu 10000 va 1000000 khi dung ham randint")
# Out:
# [35 14 36 13  1 16  3  4 33  3  9 17 26 13 17  2  1 25 16 13 39 39 20 39
#  12  6 15 36  7  1 11  3 34 35 16 23 32  5 26 36]
# Do thi phan phoi xac suat cua 4 truong hop tren deu co hinh dang giong nhau

# %% [markdown]
# ### Bài 4: Mô phỏng cách chọn mẫu
#
# Trong bài tập này ta sẽ mô phỏng cách lấy mẫu từ một tập đã có sẵn.
#
# a. Sử dụng hàm `randint()` để tạo 10 số ngẫu nhiên nằm trong đoạn [1..100]. Lưu kết quả vào biến `my_arr`
#
# b. Sử dụng hàm `choice` để lấy ngẫu nhiên 5 phần tử từ mảng `my_arr`.
#
# c. Thực hiện câu b, 10 lần. Với mỗi lần bạn hãy hiển thị 5 phần tử được chọn, tính giá trị trung bình và độ lệch chuẩn của các phần tử ấy

# %%
# YOUR CODE HERE
my_arr = np.random.randint(1, 100, 100)
# su dung choice de lay ngau nhien 5 value
value_random = my_arr[np.random.choice(100, 5)]
print(value_random)
print(value_random.mean())

for i in range(9):
    print(my_arr[np.random.choice(100, 5)])
    print(my_arr[np.random.choice(100, 5)].mean())
    print(my_arr[np.random.choice(100, 5)].std())
print("Ta thay duoc gia tri trung binh cua 10 lan hau nhu la ngang nhau va deu co gia tri xap xi 50")
print("Gia tri do lech chuan cua 10 lan cung co gia tri xap xi 30")
# Out:
# [91 30 67  6 86]
# 56.0
# [38 24 34 93 48]
# 48.8
# 26.188547115103578
# [67 25 25 68 88]
# 34.2
# 27.03035330882673
# [12 46 65 15 60]
# 47.6
# 22.26566864030811
# [16  1  6 30 86]
# 59.4
# 32.480147782915026
# [ 3  6 87  6 78]
# 30.6
# 20.558210038814178
# [95 22 67 73 78]
# 35.4
# 25.168233946782994
# [94 24 33 24 25]
# 45.0
# 27.491089465497726
# [ 6 48 70 76 34]
# 40.8
# 26.725268941584105
# [93 76 79 93 29]
# 49.8
# 28.366177042386237

# %% [markdown]
# ### Bài 5 Kiểm tra mảng phát sinh
#
# Giả sử chiều cao của người trưởng thành dao động từ 140cm - 210cm.
#
# a. Bạn hãy phát sinh ngẫu nhiên chiều cao của 1000 người và lưu vào mảng `heights`
#
# b. Giả sử ta quy định mức chiều cao như sau:
#
# - Mức thấp: chiều cao bé hơn 160cm
# - Mức bình thường: chiều cao từ 160 đến bé hơn 175cm
# - Mức cao: chiều cao từ 175cm đến bé hơn 190cm
# - Mức rất cao: chiều cao từ 190cm trở lên
#
# Từ mảng đã phát sinh bạn hãy tính tỷ lệ mỗi mức. Lựa chọn đồ thị phù hợp để biểu diễn.

# %%
# YOUR CODE HERE
heights = np.random.randint(140, 210, 1000)
print("Muc thap : ", heights[(heights < 160)].size)
print("Muc vua : ", heights[(heights >= 160) & (heights < 175)].size)
print("Muc cao : ", heights[(heights >= 175)].size)
print("Muc rat cao : ", heights[(heights >= 190)].size)
# tinh ty le moi muc
print("Ty le muc thap : ", heights[(heights < 160)].size / heights.size)
print("Ty le muc vua : ", heights[(heights >= 160) & (heights < 175)].size / heights.size)
print("Ty le muc cao : ", heights[(heights >= 175)].size / heights.size)
print("Ty le muc rat cao : ", heights[(heights >= 190)].size / heights.size)
# ve do thi
plt.hist(heights, bins = 70)
plt.show()
# Out:
# Muc thap :  282
# Muc vua :  222
# Muc cao :  496
# Muc rat cao :  283
# Ty le muc thap :  0.282
# Ty le muc vua :  0.222
# Ty le muc cao :  0.496
# Ty le muc rat cao :  0.283

# %% [markdown]
# ## DỮ LIỆU

# %% [markdown]
# ### Bài 6: dataset `temperature.csv`
#
# Bạn hãy tìm cách đọc dữ liệu về nhiệt độ của các tỉnh thành trên với thư viện `numpy`.
#
# a. Với mỗi tỉnh thành bạn hãy cho biết: nhiệt độ thấp nhất, nhiệt độ cao nhất, nhiệt độ trung bình, độ lệch chuẩn, độ biến thiên về nhiệt độ (`range=max-min`)
#
# b. Vẽ histogram nhiệt độ của TP.HCM
#
# c. Lựa chọn đồ thị để so sánh nhiệt độ của 6 tỉnh thành

# %%
import numpy as np

# Corrected function name and code
data1 = np.genfromtxt(r"D:\Quan_Ly_Mon_Hoc\Thong_Ke_May_Tinh\bai tap\datasets\temperature.csv", delimiter=',')
# Lay cot gia tri thu 5
data2 = data1[:, 5]

plt.hist(data2, bins = 100)
plt.show()
# Dung do thi phu hop so sanh 6 tinh thanh
# Vẽ đồ thị pie
labels = ["Ha Noi","Vinh","Da Nang","Nha Trang","Ho Chi Minh","Ca Mau"]
for i in range(6):
    plt.plot(data1[:, i], label = labels[i])
plt.legend()
plt.title("Nhiet do 6 tinh thanh")
plt.show()
# Out:
# Nhiet do be hon 20 do c: 0

# %% [markdown]
# ### Bài 7: dataset `bmi.csv`
#
# Bạn hãy tìm cách đọc dữ liệu về bmi của nhóm người khảo sát trên với thư viện `numpy`.
#
# a. Hãy cho biết:
#     - Tỷ lệ nam nữ
#     - Các đại lượng thống kê: min, max, range, mean, standard deviation của hai thuộc tính chiều cao và cân nặng
#
# b. Vẽ đồ thị histogram về chiều cao và cân nặng của hai thuộc tính chiều cao và cân nặng
#
# c. Sử dụng hai đồ thị boxplot để so sánh chiều cao và cân nặng của nam và nữ
#
# d. Để kiểm tra xem hai thuộc tính chiều cao và cân nặng có mối liên quan nào hay không, bạn có thể sử dụng đồ thị tán xạ (scatter plot). Giả sử muốn kiểm tra xem liệu một người cao hơn thì có cân nặng lớn hơn hay không, bạn hãy vẽ đồ thị scatter plot với trục hoành là chiều cao và trục tung là cân nặng

# %%
# YOUR CODE HERE
import numpy as np

# Corrected function name and code
data3 = np.genfromtxt(r"D:\Quan_Ly_Mon_Hoc\Thong_Ke_May_Tinh\bai tap\datasets\bmi.csv", delimiter=',',dtype=str)
data2 = np.genfromtxt(r"D:\Quan_Ly_Mon_Hoc\Thong_Ke_May_Tinh\bai tap\datasets\bmi.csv", delimiter=',')
data_nam = data3[(data3[:, 1] == 'Male')]
data_nu = data3[data3[:, 1] == 'Female']
print("So luong nam:", data_nam.shape[0])
print("So luong nu:", data_nu.shape[0])
print("Tinh ty le nam va nu la:", data_nam.shape[0] / data3.shape[0])
print("Tinh ty le nam va nu la:", data_nu.shape[0] / data3.shape[0])


# Thong ke theo mot so 3 va so 4. Va bat dau tu dong 1
print("Mean - Can nang:", np.mean(data2[1:, 3]))
print("Std - Can nang:", np.std(data2[1:, 3]))
print("MIN - Can nang:", np.min(data2[1:, 3]))
print("MAX - Can nang:", np.max(data2[1:, 3]))
print("Range - Can nang:", np.max(data2[1:, 3]) - np.min(data2[1:, 3]))

print("Mean - Chieu cao:", np.mean(data2[1:, 2]))
print("Std - Chieu cao:", np.std(data2[1:, 2]))
print("MIN - Chieu cao:", np.min(data2[1:, 2]))
print("MAX - Chieu cao:", np.max(data2[1:, 2]))
print("Range - Chieu cao:", np.max(data2[1:, 2]) - np.min(data2[1:, 2]))

plt.hist(data2[1:, 3], bins=100)
plt.title("Can nang")
plt.show()
plt.hist(data2[1:, 2], bins=100)
plt.title("Chieu cao")
plt.show()

# Boxplot for weight and height by gender
weights_male = data2[data3[:, 1] == 'Male', 3]
weights_female = data2[data3[:, 1] == 'Female', 3]

heights_male = data2[data3[:, 1] == 'Male', 2]
heights_female = data2[data3[:, 1] == 'Female', 2]

plt.boxplot([weights_male, weights_female], labels=['Nam', 'Nữ'])
plt.title("Boxplot - Cân nặng theo giới tính")
plt.ylabel("Cân nặng")
plt.show()

plt.boxplot([heights_male, heights_female], labels=['Nam', 'Nữ'])
plt.title("Boxplot - Chiều cao theo giới tính")
plt.ylabel("Chiều cao")
plt.show()
# Out:
# So luong nam: 245
# So luong nu: 255
# Tinh ty le nam va nu la: 0.48902195608782434
# Tinh ty le nam va nu la: 0.5089820359281437
# Mean - Can nang: 106.0
# Std - Can nang: 32.350208654659404
# MIN - Can nang: 50.0
# MAX - Can nang: 160.0
# Range - Can nang: 110.0
# Mean - Chieu cao: 169.944
# Std - Chieu cao: 16.35887722308594
# MIN - Chieu cao: 140.0
# MAX - Chieu cao: 199.0
# Range - Chieu cao: 59.0
# C:\Users\nguye\AppData\Local\Temp\ipykernel_24148\1430108240.py:42: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([weights_male, weights_female], labels=['Nam', 'Nữ'])
# C:\Users\nguye\AppData\Local\Temp\ipykernel_24148\1430108240.py:47: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([heights_male, heights_female], labels=['Nam', 'Nữ'])

# %% [markdown]
# ## KHÁC

# %% [markdown]
# ### Bài 8: Mô phỏng điểm bài kiểm tra
#
# Giả sử điểm bài kiểm tra của học sinh có điểm môn Toán [0..10], với các phần lẻ có thể có là [0.25, 0.5, 0.75]
#
# a. Dùng hàm ngẫu nhiên để phát sinh điểm số của một lớp học gồm của 10 học sinh. Tính điểm trung bình của lớp đó.
#
# b. Giả sử một trường có 50 lớp học. Mỗi lớp học có 40 học sinh. Bạn hãy phát sinh ngẫu nhiên điểm của các học sinh trong 50 lớp học này
#
# c. Giả sử nhà trường muốn thống kê tình hình học tập của 50 lớp học này. Nhà trường tiến hành thống kê bằng cách lấy điểm trung bình của tất cả các lớp học. Bạn hãy vẽ histogram điểm trung bình của 50 lớp học này.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Bài 9: Mô phỏng bốc ba lá bài
#
# Một bộ bài tú lơ khơ có 52 lá. Với:
#     - Tập các nút là {2, 3,..10, J, Q, K, A}
#     - Tập các chất là {'co', 'ro', 'chuong', 'bich`}
#
# Bạn hãy mô phỏng:
#
# a. Bốc 3 lá bài từ bộ bài trên. Lưu ý: không có trường hợp 1 bộ bài có hai lá trùng nhau
#
# b. Tính điểm thu được (tổng điểm 3 lá)
#
# c. Tìm hiểu cách hiển thị hình ảnh 3 lá bài đã bốc bằng python

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Bài 10: Mô phỏng Monte Carlo để ước lượng π
#
# Ước lượng giá trị của π bằng phương pháp Monte Carlo. Ý tưởng là tạo ngẫu nhiên các điểm trong một hình vuông và xác định tỷ lệ các điểm nằm trong một phần tư hình tròn.
#
# Công việc:
#
# Tạo 100.000 điểm ngẫu nhiên (x, y) trong một hình vuông đơn vị.
# Đếm số điểm nằm trong phần tư hình tròn có bán kính 1.
# Ước lượng π bằng công thức: 4 * (số điểm trong hình tròn) / (tổng số điểm).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
